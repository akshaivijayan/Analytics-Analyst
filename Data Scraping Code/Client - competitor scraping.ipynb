# %%
# !pip3 install wordcloud
# !pip3 install matplotlib

# %% [markdown]
# # Event Queen

# %%
import requests
import collections
import numpy as np
import collections
import numpy as np
import pandas as pd
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
req = requests.get("https://rsgevents.ca/about/")
req1 = requests.get("https://vestievents.com/")
req2 = requests.get("https://eventqueen.ca/services")
soup= BeautifulSoup(req.content,"html.parser")
soup1 = BeautifulSoup(req1.content,"html.parser")
soup2 = BeautifulSoup(req2.content,"html.parser")
#print(soup.prettify())
res=soup.title
#at=soup.find(id="providerInfo")
at2 = soup2.find(id = "d471dc90-7503-4aff-9829-c07a22e68810")


#print(at.get_text())
#d = d + at1.get_text()  + a + b +"From intimate gatherings to larger scale weddings and events, the Chic by Nicole team is committed to working with couples to bring their visions to life and ensure their events run flawlessly.  Named one of the Top Wedding Planners worldwide by VOGUE Magazine and Black planner to follow by Martha Stewart Weddings, we offer bespoke services and design proposals that are both romantic, timeless and approachable. We provide full service wedding management and styling services in Toronto, Napa, Niagara Falls, New York, Paris and Worldwide"
d= at2.get_text() 
print(d) 


from matplotlib import rcParams
from wordcloud import WordCloud, STOPWORDS
all_headlines=d
stopwords = STOPWORDS
wordcloud = WordCloud(stopwords=stopwords, background_color="white", max_words=1000).generate(all_headlines)
rcParams['figure.figsize'] = 10, 20

plt.imshow(wordcloud)
plt.axis("off")
plt.show()
filtered_words = [word for word in all_headlines.split() if word not in stopwords]
counted_words = collections.Counter(filtered_words)
words = []
counts = []
for letter, count in counted_words.most_common(10):
    words.append(letter)
    counts.append(count)
colors = cm.rainbow(np.linspace(0, 1, 10))
rcParams['figure.figsize'] = 20, 10
plt.title('Top words in the headlines vs their count')
plt.xlabel('Count')
plt.ylabel('Words')
plt.barh(words, counts, color=colors)
plt.show()
# Out:
#  Services Event PlanningOur event planning services start with taking the time to understand what you really want. We will connect you with the right vendors, and together we will plan an event to remember.Event ConsultationIf you have questions about an event that you are planning, we can help with that as well. We offer consultations on venue contracts, scheduling, and permitting. Event ManagementPlanning an event is only part of the process. Our staff will make sure that everything goes smoothly with your event. We know how to anticipate problems before they happen, leaving you free to enjoy your festivities.

# %% [markdown]
# # RSG Events

# %%
import requests
import collections
import numpy as np
import collections
import numpy as np
import pandas as pd
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
req = requests.get("https://rsgevents.ca/about/")
req1 = requests.get("https://vestievents.com/")
req2 = requests.get("https://eventqueen.ca/services")
soup= BeautifulSoup(req.content,"html.parser")
soup1 = BeautifulSoup(req1.content,"html.parser")
soup2 = BeautifulSoup(req2.content,"html.parser")
#print(soup.prettify())
res=soup.title

d0 = "Raquel Sananes Grad, the creative visionary behind RSG Events, has had the pleasure of planning all types of events for a wide variety of fabulous clients including weddings, bar/bat mitzvahs, galas, soirées, charity fundraisers, corporate events, and golf tournaments."

d1 = "Raquel is an inspired team leader and consummate collaborator who always wins the trust and respect of clients and colleagues."

d2 = "With excellent communication and organizational skills and a self-proclaimed motto to “always be part of the solution,” Raquel is often several steps ahead of her clients’ needs during the planning process. She is best known for her uniquely creative concepts and flawless attention to detail."

d3 = "Raquel takes the client’s vision to an epic new level, orchestrating truly spectacular and original celebrations."

d4 = "Raquel’s goal is simple: To use her knowledge and expertise to bring your vision to life. She has the experience to manage the logistics behind every type of event. From a small, intimate wedding of 50 people to a large, elaborate charity fundraiser or corporate event of 2,000 people, Raquel can do it all! No detail is too small, no challenge is too big."

d5 = "Raquel can help you plan your perfect event. From selecting the right professionals and helping you save money to being there on the day of the event until the very end, Raquel will ensure that your affair is a worry-free affair."

d6 = "Whatever the occasion, whatever the event, Raquel is the right choice for you."

d7 = "Want to learn more? Contact Raquel today for a free, no-obligation consultation."

#print(at.get_text())
#d = d + at1.get_text()  + a + b +"From intimate gatherings to larger scale weddings and events, the Chic by Nicole team is committed to working with couples to bring their visions to life and ensure their events run flawlessly.  Named one of the Top Wedding Planners worldwide by VOGUE Magazine and Black planner to follow by Martha Stewart Weddings, we offer bespoke services and design proposals that are both romantic, timeless and approachable. We provide full service wedding management and styling services in Toronto, Napa, Niagara Falls, New York, Paris and Worldwide"
d= d0 + d1 + d2 + d3 + d4 + d5 + d6 + d7
print(d) 


from matplotlib import rcParams
from wordcloud import WordCloud, STOPWORDS
all_headlines=d
stopwords = STOPWORDS
wordcloud = WordCloud(stopwords=stopwords, background_color="white", max_words=1000).generate(all_headlines)
rcParams['figure.figsize'] = 10, 20

plt.imshow(wordcloud)
plt.axis("off")
plt.show()
filtered_words = [word for word in all_headlines.split() if word not in stopwords]
counted_words = collections.Counter(filtered_words)
words = []
counts = []
for letter, count in counted_words.most_common(10):
    words.append(letter)
    counts.append(count)
colors = cm.rainbow(np.linspace(0, 1, 10))
rcParams['figure.figsize'] = 20, 10
plt.title('Top words in the headlines vs their count')
plt.xlabel('Count')
plt.ylabel('Words')
plt.barh(words, counts, color=colors)
plt.show()
# Out:
# Raquel Sananes Grad, the creative visionary behind RSG Events, has had the pleasure of planning all types of events for a wide variety of fabulous clients including weddings, bar/bat mitzvahs, galas, soirées, charity fundraisers, corporate events, and golf tournaments.Raquel is an inspired team leader and consummate collaborator who always wins the trust and respect of clients and colleagues.With excellent communication and organizational skills and a self-proclaimed motto to “always be part of the solution,” Raquel is often several steps ahead of her clients’ needs during the planning process. She is best known for her uniquely creative concepts and flawless attention to detail.Raquel takes the client’s vision to an epic new level, orchestrating truly spectacular and original celebrations.Raquel’s goal is simple: To use her knowledge and expertise to bring your vision to life. She has the experience to manage the logistics behind every type of event. From a small, intimate wedding o
# ...

# %% [markdown]
# # Vesti Events

# %%
import requests
import collections
import numpy as np
import collections
import numpy as np
import pandas as pd
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
req = requests.get("https://rsgevents.ca/about/")
req1 = requests.get("https://vestievents.com/")
req2 = requests.get("https://eventqueen.ca/services")
soup= BeautifulSoup(req.content,"html.parser")
soup1 = BeautifulSoup(req1.content,"html.parser")
soup2 = BeautifulSoup(req2.content,"html.parser")
#print(soup.prettify())
res=soup.title
#at=soup.find(id="providerInfo")

# a = "Planners (CIP) – the national association. The Institute was incorporated in 1958 under the Society Act of British Columbia with just eight founding members. There are currently close to 1,600 members.Professional members of PIBC are forward thinking individuals who work in both the public and private sectors and in many different fields of planning including: land-use and development, municipal and regional planning, resource and environmental management, policy planning and law, heritage conservation, transportation planning, economic development, urban design and more.Professional planners use their knowledge, skills and experience to help shape more livable, sustainable communities and environments. PIBC members are forward thinking individuals who work in both the public and private sectors, in many different fields of planning – including land-use and development, municipal and regional planning, resource and environmental management, policy planning and law, heritage conservation, transportation planning, economic development, urban design, and more."
# b = "Some of our favourite Toronto and Paris wedding venues include Casa Loma, Graydon Hall Manor, The Ritz Paris, Shangri-La Hotel, Le Crillon and Langon Hall just to name a few. We offer destination planning collections in France, Italy and Mexico that include travel concierge services.The Planning Institute of British Columbia (PIBC) is the professional association of planners in British Columbia and the Yukon and has been dedicated to the advancement of the planning profession for more than 60 years. PIBC is the westernmost affiliate of the Canadian Institute of"
c = "Have a vision but don’t know where to start ? The team at VESTI Events will guide you through a step by step checklist in order to execute your event with peace of mind. Our concierge services include direct contacts at the City of Vancouver, as well as many local business and vendor connections"

#print(at.get_text())
#d = d + at1.get_text()  + a + b +"From intimate gatherings to larger scale weddings and events, the Chic by Nicole team is committed to working with couples to bring their visions to life and ensure their events run flawlessly.  Named one of the Top Wedding Planners worldwide by VOGUE Magazine and Black planner to follow by Martha Stewart Weddings, we offer bespoke services and design proposals that are both romantic, timeless and approachable. We provide full service wedding management and styling services in Toronto, Napa, Niagara Falls, New York, Paris and Worldwide"
d= c  
print(d) 


from matplotlib import rcParams
from wordcloud import WordCloud, STOPWORDS
all_headlines=d
stopwords = STOPWORDS
wordcloud = WordCloud(stopwords=stopwords, background_color="white", max_words=1000).generate(all_headlines)
rcParams['figure.figsize'] = 10, 20

plt.imshow(wordcloud)
plt.axis("off")
plt.show()
filtered_words = [word for word in all_headlines.split() if word not in stopwords]
counted_words = collections.Counter(filtered_words)
words = []
counts = []
for letter, count in counted_words.most_common(10):
    words.append(letter)
    counts.append(count)
colors = cm.rainbow(np.linspace(0, 1, 10))
rcParams['figure.figsize'] = 20, 10
plt.title('Top words in the headlines vs their count')
plt.xlabel('Count')
plt.ylabel('Words')
plt.barh(words, counts, color=colors)
plt.show()
# Out:
# Have a vision but don’t know where to start ? The team at VESTI Events will guide you through a step by step checklist in order to execute your event with peace of mind. Our concierge services include direct contacts at the City of Vancouver, as well as many local business and vendor connections

# %% [markdown]
# # All Together

# %%
import requests
import collections
import numpy as np
import collections
import numpy as np
import pandas as pd
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
req = requests.get("https://rsgevents.ca/about/")
req1 = requests.get("https://vestievents.com/")
req2 = requests.get("https://eventqueen.ca/services")
soup= BeautifulSoup(req.content,"html.parser")
soup1 = BeautifulSoup(req1.content,"html.parser")
soup2 = BeautifulSoup(req2.content,"html.parser")
#print(soup.prettify())
res=soup.title
#at=soup.find(id="providerInfo")
at1 = soup1.find(id = "about")
at2 = soup2.find(id = "d471dc90-7503-4aff-9829-c07a22e68810")
# a = "Planners (CIP) – the national association. The Institute was incorporated in 1958 under the Society Act of British Columbia with just eight founding members. There are currently close to 1,600 members.Professional members of PIBC are forward thinking individuals who work in both the public and private sectors and in many different fields of planning including: land-use and development, municipal and regional planning, resource and environmental management, policy planning and law, heritage conservation, transportation planning, economic development, urban design and more.Professional planners use their knowledge, skills and experience to help shape more livable, sustainable communities and environments. PIBC members are forward thinking individuals who work in both the public and private sectors, in many different fields of planning – including land-use and development, municipal and regional planning, resource and environmental management, policy planning and law, heritage conservation, transportation planning, economic development, urban design, and more."
# b = "Some of our favourite Toronto and Paris wedding venues include Casa Loma, Graydon Hall Manor, The Ritz Paris, Shangri-La Hotel, Le Crillon and Langon Hall just to name a few. We offer destination planning collections in France, Italy and Mexico that include travel concierge services.The Planning Institute of British Columbia (PIBC) is the professional association of planners in British Columbia and the Yukon and has been dedicated to the advancement of the planning profession for more than 60 years. PIBC is the westernmost affiliate of the Canadian Institute of"
c = "Have a vision but don’t know where to start ? The team at VESTI Events will guide you through a step by step checklist in order to execute your event with peace of mind. Our concierge services include direct contacts at the City of Vancouver, as well as many local business and vendor connections"
d0 = "Raquel Sananes Grad, the creative visionary behind RSG Events, has had the pleasure of planning all types of events for a wide variety of fabulous clients including weddings, bar/bat mitzvahs, galas, soirées, charity fundraisers, corporate events, and golf tournaments."

d1 = "Raquel is an inspired team leader and consummate collaborator who always wins the trust and respect of clients and colleagues."

d2 = "With excellent communication and organizational skills and a self-proclaimed motto to “always be part of the solution,” Raquel is often several steps ahead of her clients’ needs during the planning process. She is best known for her uniquely creative concepts and flawless attention to detail."

d3 = "Raquel takes the client’s vision to an epic new level, orchestrating truly spectacular and original celebrations."

d4 = "Raquel’s goal is simple: To use her knowledge and expertise to bring your vision to life. She has the experience to manage the logistics behind every type of event. From a small, intimate wedding of 50 people to a large, elaborate charity fundraiser or corporate event of 2,000 people, Raquel can do it all! No detail is too small, no challenge is too big."

d5 = "Raquel can help you plan your perfect event. From selecting the right professionals and helping you save money to being there on the day of the event until the very end, Raquel will ensure that your affair is a worry-free affair."

d6 = "Whatever the occasion, whatever the event, Raquel is the right choice for you."

d7 = "Want to learn more? Contact Raquel today for a free, no-obligation consultation."

#print(at.get_text())
#d = d + at1.get_text()  + a + b +"From intimate gatherings to larger scale weddings and events, the Chic by Nicole team is committed to working with couples to bring their visions to life and ensure their events run flawlessly.  Named one of the Top Wedding Planners worldwide by VOGUE Magazine and Black planner to follow by Martha Stewart Weddings, we offer bespoke services and design proposals that are both romantic, timeless and approachable. We provide full service wedding management and styling services in Toronto, Napa, Niagara Falls, New York, Paris and Worldwide"
d= at2.get_text() + c + d0 + d1 + d2 + d3 + d4 + d5 + d6 + d7
print(d) 


from matplotlib import rcParams
from wordcloud import WordCloud, STOPWORDS
all_headlines=d
stopwords = STOPWORDS
wordcloud = WordCloud(stopwords=stopwords, background_color="white", max_words=1000).generate(all_headlines)
rcParams['figure.figsize'] = 10, 20

plt.imshow(wordcloud)
plt.axis("off")
plt.show()
filtered_words = [word for word in all_headlines.split() if word not in stopwords]
counted_words = collections.Counter(filtered_words)
words = []
counts = []
for letter, count in counted_words.most_common(10):
    words.append(letter)
    counts.append(count)
colors = cm.rainbow(np.linspace(0, 1, 10))
rcParams['figure.figsize'] = 20, 10
plt.title('Top words in the headlines vs their count')
plt.xlabel('Count')
plt.ylabel('Words')
plt.barh(words, counts, color=colors)
plt.show()
# Out:
#  Services Event PlanningOur event planning services start with taking the time to understand what you really want. We will connect you with the right vendors, and together we will plan an event to remember.Event ConsultationIf you have questions about an event that you are planning, we can help with that as well. We offer consultations on venue contracts, scheduling, and permitting. Event ManagementPlanning an event is only part of the process. Our staff will make sure that everything goes smoothly with your event. We know how to anticipate problems before they happen, leaving you free to enjoy your festivities. Have a vision but don’t know where to start ? The team at VESTI Events will guide you through a step by step checklist in order to execute your event with peace of mind. Our concierge services include direct contacts at the City of Vancouver, as well as many local business and vendor connectionsRaquel Sananes Grad, the creative visionary behind RSG Events, has had the pleasur
# ...
